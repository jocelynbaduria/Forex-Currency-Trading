# %% [markdown]
# <a href="https://colab.research.google.com/github/jocelynbaduria/Forex-Currency-Trading/blob/main/RLProject_FX_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install coloredlogs
# Out:
# ...
#      |████████████████████████████████| 46 kB 1.9 MB/s
# ...
#      |████████████████████████████████| 86 kB 3.7 MB/s
# ...

# %%
# !pip install ta==0.5.11
# Out:
# ...
#   Created wheel for ta: filename=ta-0.5.11-py3-none-any.whl size=23029 sha256=9433cc8d3a319b28f8f55083712ba39a50f35883fd4c1d52e3bb1b5e36d89d3a
#   Stored in directory: /root/.cache/pip/wheels/45/74/7e/0cf9eecab5621f01996c5dc45c83da2b4d4a236281c6058fcf
# Successfully built ta
# ...

# %%
# %cd /content/drive/Shareddrives/cmpe_260_RL_Project/code/RL-DeepQLearning-Tradingv1/
# Out:
# /content/drive/Shareddrives/cmpe_260_RL_Project/code/RL-DeepQLearning-Tradingv1

# %% [markdown]
# ### Train EUR currency (pg_1637720589_10)

# %%
# !python train.py --train data/EUR_NC.csv.csv --valid data/EUR_NC.csv --model-type=pg --episode-count 50 --window-size 10
# Out:
# 2021-11-24 02:19:36 4d759746decd root[364] DEBUG Switching --> TensorFlow for CPU
# 2021-11-24 02:19:36 4d759746decd numexpr.utils[364] INFO NumExpr defaulting to 2 threads.
# Using policy gradient model
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning:
#
# The `lr` argument is deprecated, use `learning_rate` instead.
#
# 2021-11-24 02:19:37.380527: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 256)               7424
#
#  dense_1 (Dense)             (None, 512)               131584
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  dense_3 (Dense)             (None, 256)               131328
#
# ...

# %% [markdown]
# ### Train INR currency (pg_1637721954_10)

# %%
# !python train.py --train data/INR_NC.csv.csv --valid data/INR_NC.csv --model-type=pg --episode-count 50 --window-size 10
# Out:
# 2021-11-24 02:42:20 4d759746decd root[131795] DEBUG Switching --> TensorFlow for CPU
# 2021-11-24 02:42:20 4d759746decd numexpr.utils[131795] INFO NumExpr defaulting to 2 threads.
# Using policy gradient model
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning:
#
# The `lr` argument is deprecated, use `learning_rate` instead.
#
# 2021-11-24 02:42:20.867867: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 256)               7424
#
#  dense_1 (Dense)             (None, 512)               131584
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  dense_3 (Dense)             (None, 256)               131328
#
# ...

# %% [markdown]
# ### Train PHP currency (pg_1637724189_10)

# %%
# !python train.py --train data/PHP_NC.csv.csv --valid data/PHP_NC.csv --model-type=pg --episode-count 50 --window-size 10
# Out:
# 2021-11-24 03:19:36 4d759746decd root[263242] DEBUG Switching --> TensorFlow for CPU
# 2021-11-24 03:19:37 4d759746decd numexpr.utils[263242] INFO NumExpr defaulting to 2 threads.
# Using policy gradient model
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning:
#
# The `lr` argument is deprecated, use `learning_rate` instead.
#
# 2021-11-24 03:19:37.673743: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 256)               7424
#
#  dense_1 (Dense)             (None, 512)               131584
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  dense_3 (Dense)             (None, 256)               131328
#
# ...
